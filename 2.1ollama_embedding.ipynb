# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embedding = (
    OllamaEmbeddings(model="ollama run gemma2:2b")

)
# Out:
# C:\Users\91767\AppData\Local\Temp\ipykernel_9488\1641628019.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="ollama run gemma2:2b")

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings

# Initialize the embedding with the correct model name
embedding = OllamaEmbeddings(model="gemma2")  # Use only the model name, e.g., "gemma2"

# Embed the documents
r1 = embedding.embed_documents(
    [
        "I have a dream today",
        "I have a dream that one day every valley shall be engulfed, every hill shall be exalted and every mountain shall be made low",
        "The rough places will be made plains and the crooked places will be made straight",
        "The glory of the Lord shall be revealed and all flesh shall see it together",
        "So even though we face the difficulties of today and tomorrow, I still have a dream"
    ]
)

print(r1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       4 embedding = OllamaEmbeddings(model="gemma2")  # Use only the model name, e.g., "gemma2"
#       6 # Embed the documents
# ----> 7 r1 = embedding.embed_documents(
#       8     [
#       9         "I have a dream today",
#      10         "I have a dream that one day every valley shall be engulfed, every hill shall be exalted and every mountain shall be made low",
#      11         "The rough places will be made plains and the crooked places will be made straight",
#      12         "The glory of the Lord shall be revealed and all flesh shall see it together",
#      13         "So even though we face the difficulties of today and tomorrow, I still have a dream"
#      14     ]
#      15 )
#      17 print(r1)
#
# ...

# %%
embedding = OllamaEmbeddings(model="gemma2:2b")

# %%
embedding = OllamaEmbeddings(model = "nomic-embed-text")
text = "hii bro how are you"
query_result = embedding.embed_query(text)
query_result
# Out:
# [-0.46840164065361023,
#  0.14334328472614288,
#  -3.123525381088257,
#  1.0252166986465454,
#  0.34818607568740845,
#  0.10787486284971237,
#  0.6165629625320435,
#  -0.2091314196586609,
#  -0.32648545503616333,
#  -1.036314845085144,
#  -0.18985028564929962,
#  0.7552133202552795,
#  -0.6923598051071167,
#  0.6370347738265991,
#  1.931247353553772,
#  -0.7900441884994507,
#  -0.15078195929527283,
#  -1.1004159450531006,
#  -0.09001047164201736,
#  -0.08197304606437683,
#  -1.2066752910614014,
#  -0.5651676654815674,
#  -1.4229564666748047,
#  -0.22479283809661865,
#  2.6912424564361572,
#  -0.9455470442771912,
#  0.062070880085229874,
#  0.7368214726448059,
#  0.21172286570072174,
#  -0.018741944804787636,
#  0.7067756652832031,
#  0.2792871296405792,
#  0.7987769842147827,
#  -0.22087633609771729,
#  0.10373728722333908,
#  0.8251017332077026,
#  0.40133488178253174,
#  0.35237663984298706,
#  0.4097425937652588,
#  0.6089358925819397,
#  0.5192061066627502,
# ...
